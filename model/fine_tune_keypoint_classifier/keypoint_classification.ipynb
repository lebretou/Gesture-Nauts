# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42
# Out:
# 2024-05-10 10:21:08.053016: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# # Specify each path

# %%
import os
os.chdir("../..")
os.getcwd()
# Out:
# '/mnt/f/CSCI1430/Gesture-Nauts'

# %%
dataset = 'model/fine_tune_keypoint_classifier/keypoint_ori.csv'
classes_path = 'model/fine_tune_keypoint_classifier/keypoint_classifier_label.csv'
model_save_path = 'model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5'
tflite_save_path = 'model/fine_tune_keypoint_classifier/keypoint_classifier.tflite'

# %% [markdown]
# # Set number of classes

# %%
NUM_CLASSES = 18

# %% [markdown]
# # Dataset reading

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))
print(y_dataset)
print(len(y_dataset))
# Out:
# [ 0  0  0 ... 17 17 17]
# 8004

# %%
from sklearn.model_selection import train_test_split
from collections import Counter
from collections import OrderedDict
# stratify parameter makes a split so that the proportion of values in the sample produced will be the same as the proportion of values provided to parameter stratify
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, stratify=y_dataset, random_state=RANDOM_SEED)

# print the number of labels in each set
train_counter = OrderedDict(sorted(Counter(y_train).items()))
test_counter = OrderedDict(sorted(Counter(y_test).items()))

print("Train set:", train_counter)
print("Test set:", test_counter)
# Out:
# Train set: OrderedDict([(0, 409), (1, 383), (2, 378), (3, 409), (4, 40), (5, 378), (6, 401), (7, 383), (8, 4), (9, 392), (10, 441), (11, 382), (12, 391), (13, 378), (14, 414), (15, 423), (16, 23), (17, 374)])
# Test set: OrderedDict([(0, 137), (1, 127), (2, 126), (3, 137), (4, 14), (5, 126), (6, 133), (7, 127), (8, 2), (9, 130), (10, 147), (11, 128), (12, 131), (13, 126), (14, 138), (15, 141), (16, 7), (17, 124)])

# %%
# X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)
# # print the number of labels in each set
# train_counter = OrderedDict(sorted(Counter(y_train).items()))
# test_counter = OrderedDict(sorted(Counter(y_test).items()))

# print("Train set:", train_counter)
# print("Test set:", test_counter)

# %%
classes = np.loadtxt(classes_path, delimiter=',', dtype='str')

# %%
print(X_train.shape, y_train.shape)
# Out:
# (6003, 42) (6003,)

# %% [markdown]
# # Model building

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Layer, Input, Add,Conv2D, MaxPooling2D,Reshape
from tensorflow.keras import Model
# model = tf.keras.models.Sequential([
#     Input((21 * 2, )),
#     Dense(256, activation='relu'),
#     Dense(512, activation='relu'),
#     Dense(1024, activation='relu'),
#     Dense(1024, activation='relu'),
#     Dropout(0.2),
#     Dense(NUM_CLASSES, activation='softmax')
# ])
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv1D, MaxPooling1D, Flatten

class ResidualBlock(Layer):
    def __init__(self, units, dropout_rate=0.2, **kwargs):
        super(ResidualBlock, self).__init__(**kwargs)
        self.units = units
        self.dropout_rate = dropout_rate
        self.dense1 = Dense(units, activation='relu')
        self.bn1 = BatchNormalization()
        self.dropout1 = Dropout(dropout_rate)
        self.dense2 = Dense(units, activation='relu')
        self.bn2 = BatchNormalization()

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.bn1(x)
        x = self.dropout1(x)
        x = self.dense2(x)
        x = self.bn2(x)
        if inputs.shape[-1] == self.units:
            x = Add()([inputs, x])  # Add skip connection only if dimensions match
        return x

    def get_config(self):
        config = super(ResidualBlock, self).get_config()
        config.update({
            "units": self.units,
            "dropout_rate": self.dropout_rate
        })
        return config


# model = Sequential([
#         Input(shape=(21 * 2,)),
#         Dense(256, activation='relu'),
#         Dropout(0.3),
#         ResidualBlock(256, dropout_rate=0.3),
#         ResidualBlock(512, dropout_rate=0.3),
#         ResidualBlock(1024, dropout_rate=0.3),
#         ResidualBlock(1024, dropout_rate=0.3),
#         Dense(NUM_CLASSES, activation='softmax')
#     ])

model = Sequential([
    Input(shape=(21 * 2, )),
    Reshape((21, 2)),
    Conv1D(64, kernel_size=3, activation='relu', padding='same', ),
    Conv1D(64, kernel_size=3, activation='relu', padding='same'),
    MaxPooling1D(pool_size=2),
    Conv1D(128, kernel_size=3, activation='relu', padding='same'),
    
    MaxPooling1D(pool_size=2),
    Conv1D(256, kernel_size=3, activation='relu', padding='same'),
    Conv1D(256, kernel_size=3, activation='relu', padding='same'),

    
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.2),
    Dense(1024, activation='relu'),
    Dropout(0.1),
    Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# 2024-05-10 10:21:13.058295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-10 10:21:13.141891: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:
# 2024-05-10 10:21:13.141941: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-05-10 10:21:13.144418: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# NUM_CLASSES = 10  # Example, change this to your actual number of classes
# model = build_model(21 * 2, 10)
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 21, 2)             0
#
#  conv1d (Conv1D)             (None, 21, 64)            448
#
#  conv1d_1 (Conv1D)           (None, 21, 64)            12352
#
#  max_pooling1d (MaxPooling1D  (None, 10, 64)           0
#  )
#
#  conv1d_2 (Conv1D)           (None, 10, 128)           24704
#
#  max_pooling1d_1 (MaxPooling  (None, 5, 128)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 5, 256)            98560
#
#  conv1d_4 (Conv1D)           (None, 5, 256)            196864
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 256)           0
#  1D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 18)                18450
#
# =================================================================
# Total params: 1,926,290
# Trainable params: 1,926,290
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model checkpoint callback
log_path="model/fine_tune_keypoint_classifier/log"
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
logs_path = "model/fine_tune_keypoint_classifier/log"
if not os.path.exists(log_path):
    os.mkdir(log_path)
cm_callback = tf.keras.callbacks.TensorBoard(
            log_dir=logs_path,
            update_freq='batch',
            profile_batch=0)
# Callback for early stopping
es_callback = tf.keras.callbacks.EarlyStopping(patience=100, verbose=1)

# %%
# Model compilation
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Model training

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=2048,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, cm_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.8771 - accuracy: 0.0653
# Epoch 1: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 274ms/step - loss: 2.8771 - accuracy: 0.0653 - val_loss: 2.8180 - val_accuracy: 0.0735
# Epoch 2/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.7737 - accuracy: 0.0731
# Epoch 2: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 189ms/step - loss: 2.7737 - accuracy: 0.0731 - val_loss: 2.7242 - val_accuracy: 0.0965
# Epoch 3/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.7147 - accuracy: 0.0978
# Epoch 3: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 191ms/step - loss: 2.7147 - accuracy: 0.0978 - val_loss: 2.6385 - val_accuracy: 0.1834
# Epoch 4/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.6039 - accuracy: 0.1576
# Epoch 4: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 186ms/step - loss: 2.6039 - accuracy: 0.1576 - val_loss: 2.5284 - val_accuracy: 0.1669
# Epoch 5/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.4989 - accuracy: 0.2056
# Epoch 5: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 189ms/step - loss: 2.4989 - accuracy: 0.2056 - val_loss: 2.4187 - val_accuracy: 0.2869
# Epoch 6/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.3652 - accuracy: 0.2657
# Epoch 6: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 190ms/step - loss: 2.3652 - accuracy: 0.2657 - val_loss: 2.2255 - val_accuracy: 0.3078
# Epoch 7/1000
# 3/3 [==============================] - ETA: 0s - loss: 2.1823 - accuracy: 0.3077
# Epoch 7: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s
saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 190ms/step - loss: 0.4221 - accuracy: 0.8559 - val_loss: 0.4849 - val_accuracy: 0.8431
# Epoch 122/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.4335 - accuracy: 0.8522
# Epoch 122: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 199ms/step - loss: 0.4335 - accuracy: 0.8522 - val_loss: 0.4622 - val_accuracy: 0.8501
# Epoch 123/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.8579
# Epoch 123: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 187ms/step - loss: 0.4138 - accuracy: 0.8579 - val_loss: 0.4737 - val_accuracy: 0.8456
# Epoch 124/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.8647
# Epoch 124: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 190ms/step - loss: 0.4074 - accuracy: 0.8647 - val_loss: 0.4553 - val_accuracy: 0.8526
# Epoch 125/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.8681
# Epoch 125: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 187ms/step - loss: 0.3942 - accuracy: 0.8681 - val_loss: 0.4745 - val_accuracy: 0.8436
# Epoch 126/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.4018 - accuracy: 0.8656
# Epoch 126: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 190ms/step - loss: 0.4018 - accuracy: 0.8656 - val_loss: 0.4539 - val_accuracy: 0.8486
# Epoch 127/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3903 - accuracy: 0.8689
# Epoch 127: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 185ms/step - loss: 0.3903 - accuracy: 0.8689 - val_loss: 0.4453 - val_accuracy: 0.8541
# Epoch 128/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3831 - accuracy: 0.8704
# Epoch 128: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 185ms/step - loss: 0.3831 - accuracy: 0.8704 - val_loss: 0.4529 - val_accuracy: 0.8551
# Epoch 129/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8706
# Epoch 129: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 183ms/step - loss: 0.3852 - accuracy: 0.8706 - val_loss: 0.4538 - val_accuracy: 0.8566
# Epoch 130/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8686
# Epoch 130: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 192ms/step - loss: 0.3864 - accuracy: 0.8686 - val_loss: 0.4627 - val_accuracy: 0.8361
# Epoch 131/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8659
# Epoch 131: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 189ms/step - loss: 0.3993 - accuracy: 0.8659 - val_loss: 0.4638 - val_accuracy: 0.8451
# Epoch 132/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3867 - accuracy: 0.8694
# Epoch 132: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 185ms/step - loss: 0.3867 - accuracy: 0.8694 - val_loss: 0.4557 - val_accuracy: 0.8576
# Epoch 133/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3896 - accuracy: 0.8689
# Epoch 133: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 186ms/step - loss: 0.3896 - accuracy: 0.8689 - val_loss: 0.4647 - val_accuracy: 0.8476
# Epoch 134/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8682
# Epoch 134: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 188ms/step - loss: 0.3880 - accuracy: 0.8682 - val_loss: 0.4487 - val_accuracy: 0.8561
# Epoch 135/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3760 - accuracy: 0.8729
# Epoch 135: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 192ms/step - loss: 0.3760 - accuracy: 0.8729 - val_loss: 0.4569 - val_accuracy: 0.8536
# Epoch 136/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8704
# Epoch 136: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 207ms/step - loss: 0.3688 - accuracy: 0.8704 - val_loss: 0.4726 - val_accuracy: 0.8431
# Epoch 137/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8717
# Epoch 137: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 189ms/step - loss: 0.3793 - accuracy: 0.8717 - val_loss: 0.4452 - val_accuracy: 0.8581
# Epoch 138/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.8701
# Epoch 138: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 187ms/step - loss: 0.3772 - accuracy: 0.8701 - val_loss: 0.4627 - val_accuracy: 0.8496
# Epoch 139/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8732
# Epoch 139: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 195ms/step - loss: 0.3691 - accuracy: 0.8732 - val_loss: 0.4433 - val_accuracy: 0.8546
# Epoch 140/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3660 - accuracy: 0.8754
# Epoch 140: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 187ms/step - loss: 0.3660 - accuracy: 0.8754 - val_loss: 0.4469 - val_accuracy: 0.8606
# Epoch 141/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8746
# Epoch 141: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 185ms/step - loss: 0.3684 - accuracy: 0.8746 - val_loss: 0.4544 - val_accuracy: 0.8581
# Epoch 142/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8806
# Epoch 142: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 187ms/step - loss: 0.3630 - accuracy: 0.8806 - val_loss: 0.4474 - val_accuracy: 0.8451
# Epoch 143/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8756
# Epoch 143: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 193ms/step - loss: 0.3637 - accuracy: 0.8756 - val_loss: 0.4374 - val_accuracy: 0.8596
# Epoch 144/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8767
# Epoch 144: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 188ms/step - loss: 0.3637 - accuracy: 0.8767 - val_loss: 0.4467 - val_accuracy: 0.8541
# Epoch 145/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8774
# Epoch 145: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 192ms/step - loss: 0.3614 - accuracy: 0.8774 - val_loss: 0.4395 - val_accuracy: 0.8626
# Epoch 146/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3509 - accuracy: 0.8791
# Epoch 146: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 187ms/step - loss: 0.3509 - accuracy: 0.8791 - val_loss: 0.4302 - val_accuracy: 0.8626
# Epoch 147/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3461 - accuracy: 0.8839
# Epoch 147: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 188ms/step - loss: 0.3461 - accuracy: 0.8839 - val_loss: 0.4297 - val_accuracy: 0.8606
# Epoch 148/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8837
# Epoch 148: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 194ms/step - loss: 0.3478 - accuracy: 0.8837 - val_loss: 0.4344 - val_accuracy: 0.8616
# Epoch 149/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3474 - accuracy: 0.8816
# Epoch 149: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 183ms/step - loss: 0.3474 - accuracy: 0.8816 - val_loss: 0.4366 - val_accuracy: 0.8566
# Epoch 150/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.8822
# Epoch 150: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 190ms/step - loss: 0.3381 - accuracy: 0.8822 - val_loss: 0.4545 - val_accuracy: 0.8556
# Epoch 151/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8816
# Epoch 151: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 190ms/step - loss: 0.3468 - accuracy: 0.8816 - val_loss: 0.4564 - val_accuracy: 0.8536
# Epoch 152/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.8857
# Epoch 152: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 187ms/step - loss: 0.3432 - accuracy: 0.8857 - val_loss: 0.4382 - val_accuracy: 0.8581
# Epoch 153/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3406 - accuracy: 0.8837
# Epoch 153: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 188ms/step - loss: 0.3406 - accuracy: 0.8837 - val_loss: 0.4666 - val_accuracy: 0.8486
# Epoch 154/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8807
# Epoch 154: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 195ms/step - loss: 0.3469 - accuracy: 0.8807 - val_loss: 0.4633 - val_accuracy: 0.8501
# ...
# Epoch 361/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9682
# Epoch 361: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 214ms/step - loss: 0.0902 - accuracy: 0.9682 - val_loss: 0.4372 - val_accuracy: 0.8916
# Epoch 362/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9655
# Epoch 362: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 207ms/step - loss: 0.0961 - accuracy: 0.9655 - val_loss: 0.4599 - val_accuracy: 0.8916
# Epoch 363/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9702
# Epoch 363: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 215ms/step - loss: 0.0870 - accuracy: 0.9702 - val_loss: 0.4894 - val_accuracy: 0.8941
# Epoch 364/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9712
# Epoch 364: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 196ms/step - loss: 0.0849 - accuracy: 0.9712 - val_loss: 0.4753 - val_accuracy: 0.8966
# Epoch 365/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9700
# Epoch 365: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 188ms/step - loss: 0.0857 - accuracy: 0.9700 - val_loss: 0.4476 - val_accuracy: 0.8921
# Epoch 366/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9738
# Epoch 366: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 199ms/step - loss: 0.0815 - accuracy: 0.9738 - val_loss: 0.4303 - val_accuracy: 0.8911
# Epoch 367/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9738
# Epoch 367: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s
saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 218ms/step - loss: 0.0607 - accuracy: 0.9802 - val_loss: 0.4957 - val_accuracy: 0.8976
# Epoch 388/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9788
# Epoch 388: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 207ms/step - loss: 0.0620 - accuracy: 0.9788 - val_loss: 0.4850 - val_accuracy: 0.8946
# Epoch 389/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9755
# Epoch 389: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 222ms/step - loss: 0.0692 - accuracy: 0.9755 - val_loss: 0.4674 - val_accuracy: 0.8971
# Epoch 390/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9782
# Epoch 390: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 208ms/step - loss: 0.0637 - accuracy: 0.9782 - val_loss: 0.4686 - val_accuracy: 0.8891
# Epoch 391/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9755
# Epoch 391: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 255ms/step - loss: 0.0666 - accuracy: 0.9755 - val_loss: 0.4632 - val_accuracy: 0.8941
# Epoch 392/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9782
# Epoch 392: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 262ms/step - loss: 0.0639 - accuracy: 0.9782 - val_loss: 0.4864 - val_accuracy: 0.8956
# Epoch 393/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9773
# Epoch 393: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 215ms/step - loss: 0.0659 - accuracy: 0.9773 - val_loss: 0.5176 - val_accuracy: 0.8966
# Epoch 394/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9785
# Epoch 394: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 194ms/step - loss: 0.0671 - accuracy: 0.9785 - val_loss: 0.4879 - val_accuracy: 0.8946
# Epoch 395/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9808
# Epoch 395: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 185ms/step - loss: 0.0617 - accuracy: 0.9808 - val_loss: 0.4765 - val_accuracy: 0.8901
# Epoch 396/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9768
# Epoch 396: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 191ms/step - loss: 0.0674 - accuracy: 0.9768 - val_loss: 0.4638 - val_accuracy: 0.8966
# Epoch 397/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9748
# Epoch 397: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 210ms/step - loss: 0.0652 - accuracy: 0.9748 - val_loss: 0.4672 - val_accuracy: 0.8946
# Epoch 398/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9785
# Epoch 398: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 209ms/step - loss: 0.0635 - accuracy: 0.9785 - val_loss: 0.4868 - val_accuracy: 0.8941
# Epoch 399/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9820
# Epoch 399: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 195ms/step - loss: 0.0571 - accuracy: 0.9820 - val_loss: 0.4681 - val_accuracy: 0.8961
# Epoch 400/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9802
# Epoch 400: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 203ms/step - loss: 0.0615 - accuracy: 0.9802 - val_loss: 0.4735 - val_accuracy: 0.8946
# Epoch 401/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9585
# Epoch 401: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 189ms/step - loss: 0.1155 - accuracy: 0.9585 - val_loss: 0.8749 - val_accuracy: 0.8436
# Epoch 402/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.2610 - accuracy: 0.9309
# Epoch 402: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 212ms/step - loss: 0.2610 - accuracy: 0.9309 - val_loss: 0.6754 - val_accuracy: 0.8556
# Epoch 403/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1954 - accuracy: 0.9455
# Epoch 403: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 185ms/step - loss: 0.1954 - accuracy: 0.9455 - val_loss: 0.5209 - val_accuracy: 0.8846
# Epoch 404/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9560
# Epoch 404: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 199ms/step - loss: 0.1313 - accuracy: 0.9560 - val_loss: 0.7123 - val_accuracy: 0.8416
# Epoch 405/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9327
# Epoch 405: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 0s 192ms/step - loss: 0.2183 - accuracy: 0.9327 - val_loss: 0.6613 - val_accuracy: 0.8461
# Epoch 406/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9269
# Epoch 406: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 201ms/step - loss: 0.2153 - accuracy: 0.9269 - val_loss: 0.4856 - val_accuracy: 0.8731
# Epoch 407/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9427
# Epoch 407: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 211ms/step - loss: 0.1661 - accuracy: 0.9427 - val_loss: 0.5349 - val_accuracy: 0.8656
# Epoch 408/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9437
# Epoch 408: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 209ms/step - loss: 0.1585 - accuracy: 0.9437 - val_loss: 0.4457 - val_accuracy: 0.8831
# Epoch 409/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9572
# Epoch 409: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 197ms/step - loss: 0.1153 - accuracy: 0.9572 - val_loss: 0.4671 - val_accuracy: 0.8806
# Epoch 410/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9575
# Epoch 410: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 219ms/step - loss: 0.1182 - accuracy: 0.9575 - val_loss: 0.4176 - val_accuracy: 0.8916
# Epoch 411/1000
# 3/3 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.9683
# Epoch 411: saving model to model/fine_tune_keypoint_classifier/keypoint_classifier.hdf5
# 3/3 [==============================] - 1s 216ms/step - loss: 0.0944 - accuracy: 0.9683 - val_loss: 0.4354 - val_accuracy: 0.8946
# Epoch 411: early stopping

# %%
# Model evaluation
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 12/16 [=====================>........] - ETA: 0s - loss: 0.4464 - accuracy: 0.8945
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4354 - accuracy: 0.8946

# %%
# Loading the saved model
model = tf.keras.models.load_model(model_save_path)

# %%
# Inference test
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 134ms/step
# [6.8668342e-08 9.9321510e-19 4.6308117e-09 9.9999893e-01 4.0654073e-12
#  1.9616992e-07 3.4195463e-12 5.9554507e-14 2.6680233e-14 2.1295312e-08
#  2.2288711e-08 1.3810968e-09 4.8811768e-09 8.1764712e-10 2.2158673e-07
#  2.2456167e-18 1.5481162e-12 4.9285990e-07]
# 3

# %% [markdown]
# # Confusion matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 5ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       137
#            1       0.83      0.91      0.87       127
#            2       0.92      0.89      0.90       126
#            3       0.83      0.77      0.80       137
#            4       0.81      0.93      0.87        14
#            5       0.88      0.89      0.88       126
#            6       0.91      0.86      0.89       133
#            7       0.85      0.87      0.86       127
#            8       1.00      1.00      1.00         2
#            9       0.75      0.85      0.80       130
#           10       0.93      0.95      0.94       147
#           11       0.85      0.84      0.84       128
#           12       0.93      0.90      0.91       131
#           13       0.94      0.91      0.93       126
#           14       0.95      0.93      0.94       138
#           15       0.97      0.98      0.97       141
#           16       1.00      0.57      0.73         7
#           17       0.92      0.89      0.91       124
#
#     accuracy                           0.89      2001
#    macro avg       0.90      0.88      0.89      2001
# weighted avg       0.90      0.89      0.89      2001

# %% [markdown]
# # Convert to model for Tensorflow-Lite

# %%
# Save as a model dedicated to inference
model.save(model_save_path, include_optimizer=False)

# %%
# Transform model (quantization)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpv8374n9m/assets
# INFO:tensorflow:Assets written to: /tmp/tmpv8374n9m/assets
# 2024-05-10 10:24:41.760526: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2024-05-10 10:24:41.760592: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2024-05-10 10:24:41.761441: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /tmp/tmpv8374n9m
# 2024-05-10 10:24:41.764294: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2024-05-10 10:24:41.764395: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /tmp/tmpv8374n9m
# 2024-05-10 10:24:41.774919: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2024-05-10 10:24:41.776883: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2024-05-10 10:24:41.850670: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /tmp/tmpv8374n9m
# 2024-05-10 10:24:41.872411: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 110978 microseconds.
# 2024-05-10 10:24:41.913221: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:263] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 1954792

# %% [markdown]
# # Inference test

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# Get I / O tensor
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# Inference implementation
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: user 5.84 ms, sys: 212 µs, total: 6.05 ms
# Wall time: 45.9 ms

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [7.2372366e-08 1.1403441e-18 5.1460023e-09 9.9999917e-01 3.9063401e-12
#  1.8209946e-07 3.6619830e-12 4.9246123e-14 3.0045959e-14 1.8991818e-08
#  1.7222236e-08 1.0175067e-09 5.0547833e-09 7.0860612e-10 1.9635301e-07
#  2.0596570e-18 1.0530652e-12 4.1253068e-07]
# 3
